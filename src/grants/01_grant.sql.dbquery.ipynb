-- %%
-- Grant yourself full ownership
GRANT ALL PRIVILEGES ON CATALOG rearc_quest TO `pronnoy1998@gmail.com`;

-- Also grant on each schema explicitly
GRANT ALL PRIVILEGES ON SCHEMA rearc_quest.bronze TO `pronnoy1998@gmail.com`;
GRANT ALL PRIVILEGES ON SCHEMA rearc_quest.silver TO `pronnoy1998@gmail.com`;
GRANT ALL PRIVILEGES ON SCHEMA rearc_quest.gold TO `pronnoy1998@gmail.com`;
GRANT ALL PRIVILEGES ON SCHEMA rearc_quest.raw TO `pronnoy1998@gmail.com`;
